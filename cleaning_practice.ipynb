# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"
#
# **Note: All solution notebooks can be found by clicking on the Jupyter icon on the top left of this workspace.**

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.
#
# Outputting all the javascript, CSS, and text may overload the space available to load this notebook, so we omit a print statement here.

# %%
# import statements
import requests
from bs4 import BeautifulSoup as bs
! pip install lxml
! pip install html5lib
# Out:
# Requirement already satisfied: lxml in /opt/conda/lib/python3.6/site-packages (4.1.1)
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from html5lib) (1.11.0)

# %%
# fetch web page
r = requests.get('https://www.udacity.com/courses/all')
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.
#
# Again, printing this entire result may overload the space available to load this notebook, so we omit a print statement here.

# %%
soup = bs(r.content, "lxml")

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just like in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
# Find all course summaries
summaries = soup.find_all("span", class_="ng-star-inserted")
print('Number of Courses:', len(summaries))
# Out:
# Number of Courses: 2096

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <script class="ng-star-inserted" type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(18),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(19),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var x=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof x&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof x&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(21)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(21)(r);n.exports=r;var i=window.history&&window.history.constructor&&wind ...
#         ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"215318720",sa:1}
#   </script>
#   <script class="ng-star-inserted" type="text/javascript">
#    (function(o){var n=Array();if(!o.performance){Object.defineProperty(o,"performance",{})}if(!o.performance.now){o.performance.now=performance.now||performance.webkitNow||performance.msNow||performance.mozNow||performance.oNow}if(!o.performance.now){var r=Date.now?Date.now():(new Date).getTime();if(performance.timing&&performance.timing){r=performance.timing.navigationStart}o.performance.now=function(){var e=Date.now?Date.now():(new Date).getTime();return e-r}}if(!o.performance.mark){var e=function(e){n.push({duration:0,entryType:"mark",name:e,startTime:o.performance.now()})};o.performance.mark=o.performance.webkitMark||e}if(!o.performance.getEntriesByType){var e=function(r){return n.filter(function(e){return e.entryType===r})};o.performance.getEntriesByType=o.performance.webkitGetEntriesByType||e}if(!o.performance.getEntriesByName){var e=function(r){return n.filter(function(e){return e.name===r})};o.performance.getEntriesByName=o.performance.webkitGetEntriesByName||e}if(!o.performance.clearMarks){var e=function(r){n=n.filter(function(e){return e.entryType!=="mark"&&(r?e.name!==r:true)})};o.performance.clearMarks=o.performance.webkitClearMarks||e}var a=function(){var e;var r=o.performance.getEntriesByType("mark");for(var n=0,a=r;n<a.length;n++){var t=a[n];if(o.NREUM){o.NREUM.addPageAction(t.name,(e={},e[t.name]=Math.round(t.startTime+t.duration),e))}}};if(window.addEventListener){window.addEventListener("load",a,false)}else if(window.attachEvent){window.attachEvent("onload",a)}})(window);
#   </script>
#   <meta name="newrelic"/>
#   <title>
#    Udacity
#   </title>
#   <base href="/"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://sgmt.udacity.com" rel="dns-prefetch"/>
#   <link href="https://classroom.udacity.com" rel="dns-prefetch"/>
#   <!-- Adobe TypeKit Script-->
#   <script>
#    (function(d) {
#       var config = {
#         kitId: 'jxo6fia',
#         scriptTimeout: 3000,
#         async: true
#       },
#       h=d.documentElement,t=setTimeout(function(){
#         h.className=h.className.replace(/\bwf-loading\b/g,"")+" wf-inactive";
#       },config.scriptTimeout),tk=d.createElement("script"),f=false,s=d.getElementsByTagName("script")[0],a;
#       h.className+=" wf-loading";tk.src='https://use.typekit.net/'+config.kitId+'.js';
#       tk.async=true;tk.onload=tk.onreadystatechange=function(){a=this.readyState;
#       if(f||a&&a!="complete"&&a!="loaded")return;f=true;clearTimeout(t);
#       try{Typekit.load(config)}catch(e){}};s.parentNode.insertBefore(tk,s)
#     })(document);
#   </script>
#   <!-- inject:js -->
#   <script async="" data-analytics-bootstrap="" src="assets/vendor/segment-b86dff1382.js">
#   </script>
#   <!-- endinject -->
#   <meta content="VBZbfME_iJOHcikGKnbO1PusPv9TQZLab4_CV8CiA-o" name="google-site-verification"/>
#   <link href="styles.0412f4d3de5fb86b36a8.css" rel="stylesheet"/>
#   <link href="/assets/styles/styles.shared.0488c0d9b4.css" name="ng-shared-styles" rel="stylesheet"/>
#   <link href="https://cn.udacity.com/courses/all" hreflang="zh-CN" rel="alternate"/>
#   <link href="https://www.udacity.com/courses/all" hreflang="en" rel="alternate"/>
#   <link href="https://www.udacity.com/courses/all" rel="canonical"/>
#  </head>
#  <body>
#   <!-- START: Debug Grid Guidelines -->
#   <!-- WARNING: Never update this to GIT -->
#   <!-- REQUIRES: enable main[.sandbox.scss|.scss] debug section -->
#   <!--<div class="grid-helper">-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--<div class="grid-column"></div>-->
#   <!--</div>-->
#   <!-- END: Debug Grid Guidelines -->
#   <ir-root _nghost-sc0="" class="page-us page-courses page-courses-all" ng-version="8.2.14">
#    <ir-nav-mobile _ngcontent-sc0="" _nghost-sc1="" class="mobile-nav__inactive">
#     <a _ngcontent-sc1="" class="logo-link" href="/" irhybridlink="/" title="Udacity">
#      <div _ngcontent-sc1="" class="logo-wordmark">
#       <svg _ngcontent-sc1="" alt="Udacity" height="30" viewbox="0 0 180 30" width="180">
#        <g _ngcontent-sc1="" fill="none" fill-rule="evenodd">
#         <path _ngcontent-sc1="" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.29385c-3.575172 0-5.95862-2.644648-5.95862-6.170846 0-3.526197 2.482758-6.072895 5.95862-6.072895 2.78069 0 4.468966 1.5672 4.468966 1.5672l.794483-1.3713s-1.787587-1.86105-5.46207-1.86105c-4.766896 0-7.746206 3.526198-7.746206 7.738045 0 4.309797 3.07862 7.933945 7.944827 7.933945 3.773793 0 5.66069-2.5467 5.66069-2.5467l-1.092414-1.175398c-.09931-.09795-1.588965 1.959-4.568276 1.959zm14.896553-14.00684h1.986206v15.67199h-1.986207zm10.924137 1.959h4.965517v13.71299h1.986207V9.794994h4.96552v-1.959H143.0069m30.587583 0l-4.766896 7.150344-4.866207-7.150347h-2.085518l5.95862 8.717546v6.954445h1.986208v-6.954444l5.85931-8.71754m-81.434482 0l-6.157242 15.67199h1.986207l1.688276-4.5057 6.45517-1.3713 2.18483 5.876998h1.986203l-6.05793-15.67199h-2.085518zm-1.886897 9.305242l2.97931-7.248294h.099315L97.92 16.063788l-5.56138 1.07745z" fill="#2E3D49" id="wordmark">
#         </path>
#         <path _ngcontent-sc1="" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z" fill="#02B3E4" id="mark">
#         </path>
#        </g>
#       </svg>
#      </div>
#     </a>
#     <nav _ngcontent-sc1="" class="header__sidenav--navigation" role="navigation">
#      <ul _ngcontent-sc1="">
#       <!-- -->
#       <!-- -->
#       <!-- -->
#       <li _ngcontent-sc1="" class="ng-star-inserted">
#        <ir-catalog-nav-mobile _ngcontent-sc1="" _nghost-sc8="">
#         <div _ngcontent-sc8="" class="catalog-nav">
#          <div _ngcontent-sc8="" data-analytics-attrs='{
#       "category": "Navbar Link",
#       "label": "Navbar Link - Mobile Header Link Clicked - Catalog",
#       "cta_message": "category_mobile_open",
#       "cta_type": "link",
#       "cta_location": "/"
#     }' data-analytics-event="Navbar Link Clicked" id="catalog-nav-mobile-open">
#           <span _ngcontent-sc8="">
#            Programs
#           </span>
#           <div _ngcontent-sc8="" class="explore-icon">
#            <svg _ngcontent-sc8="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#             <path _ngcontent-sc8="" d="M22 15.89c0 .319-.146.632-.414.82l-10.175 7.13a.868.868 0 0 1-.499.16c-.503 0-.912-.438-.912-.98V8.98c0-.186.049-.367.141-.524.27-.457.834-.593 1.26-.304l10.174 6.91c.11.075.205.174.276.292.1.165.149.35.149.533v.002z" fill-rule="evenodd">
#             </path>
#            </svg>
#           </div>
#          </div>
#          <!-- -->
#          <ul _ngcontent-sc8="" class="primary-menu-mobile ng-star-inserted">
#           <li _ngcontent-sc8="" class="close-menu" data-analytics-attrs='{
#         "category": "Navbar Link",
#         "label": "Navbar Link - Mobile Header Link Clicked - Catalog",
#         "cta_message": "category_mobile_close",
#         "cta_type": "link",
#         "cta_location": "/"
#       }' data-analytics-event="Navbar Link Clicked" id="catalog-nav-mobile-close">
#            <div _ngcontent-sc8="" class="back-icon">
#             <svg _ngcontent-sc8="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#              <path _ngcontent-sc8="" d="M9.414 15l6.293-6.293a1 1 0 1 0-1.414-1.414l-8 8a1 1 0 0 0 0 1.414l8 8a1 1 0 0 0 1.414-1.414L9.414 17H25a1 1 0 0 0 0-2H9.414z" fill-rule="nonzero">
#              </path>
#             </svg>
#            </div>
#            <span _ngcontent-sc8="" class="pull-left">
#             Back to Menu
#            </span>
#           </li>
#           <!-- -->
#           <li _ngcontent-sc8="" class="catalog-nav-school ng-star-inserted">
#            <span _ngcontent-sc8="" class="open-subnav school-link" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Mobile Header Link Clicked - Catalog - school-of-programming",
#           "cta_message": "school-of-programming",
#           "cta_type": "link",
#           "cta_location": "/"
#         }' data-analytics-event="Navbar Link Clicked" schoolpath="school-of-programming">
#             Programming and Development
#            </span>
#            <!-- -->
#            <ir-nav-sub-menu _ngcontent-sc8="" _nghost-sc20="" class="ng-star-inserted">
#             <section _ngcontent-sc20="" class="catalog-nav">
#              <ul _ngcontent-sc20="" class="catalog-nav--menu secondary-menu">
#               <!-- -->
#               <li _ngcontent-sc20="" class="close-subnav ng-star-inserted" data-analytics-attrs='{
#         "category": "Navbar Link",
#         "label": "Navbar Link - Header Link Clicked - Catalog",
#         "cta_message": "school-of-programming_subnav_mobile_close",
#         "cta_type": "link",
#         "cta_location": "/"
#       }' data-analytics-event="Navbar Link Clicked">
#                <div _ngcontent-sc20="" class="secondary-menu-item">
#                 <span _ngcontent-sc20="" class="back-icon">
#                  <svg _ngcontent-sc20="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#                   <path _ngcontent-sc20="" d="M9.414 15l6.293-6.293a1 1 0 1 0-1.414-1.414l-8 8a1 1 0 0 0 0 1.414l8 8a1 1 0 0 0 1.414-1.414L9.414 17H25a1 1 0 0 0 0-2H9.414z" fill-rule="nonzero">
#                   </path>
#                  </svg>
#                 </span>
#                 <span _ngcontent-sc20="" class="nav-back">
#                  Back to Menu
#                 </span>
#                </div>
#               </li>
#               <li _ngcontent-sc20="" class="secondary-menu-item--header">
#                <h6 _ngcontent-sc20="">
#                 Programs
#                </h6>
#               </li>
#               <!-- -->
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - front-end-web-developer-nanodegree--nd0011",
#           "cta_message": "front-end-web-developer-nanodegree--nd0011",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/front-end-web-developer-nanodegree--nd0011"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/front-end-web-developer-nanodegree--nd0011">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Front End Web Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - full-stack-web-developer-nanodegree--nd0044",
#           "cta_message": "full-stack-web-developer-nanodegree--nd0044",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/full-stack-web-developer-nanodegree--nd0044"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/full-stack-web-developer-nanodegree--nd0044">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Full Stack Web Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - java-developer-nanodegree--nd035",
#           "cta_message": "java-developer-nanodegree--nd035",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/java-developer-nanodegree--nd035"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/java-developer-nanodegree--nd035">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Java Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - cloud-developer-nanodegree--nd9990",
#           "cta_message": "cloud-developer-nanodegree--nd9990",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/cloud-developer-nanodegree--nd9990"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/cloud-developer-nanodegree--nd9990">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Cloud Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - cloud-dev-ops-nanodegree--nd9991",
#           "cta_message": "cloud-dev-ops-nanodegree--nd9991",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/cloud-dev-ops-nanodegree--nd9991"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/cloud-dev-ops-nanodegree--nd9991">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Cloud DevOps Engineer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - c-plus-plus-nanodegree--nd213",
#           "cta_message": "c-plus-plus-nanodegree--nd213",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/c-plus-plus-nanodegree--nd213"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/c-plus-plus-nanodegree--nd213">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  C++
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - data-structures-and-algorithms-nanodegree--nd256",
#           "cta_message": "data-structures-and-algorithms-nanodegree--nd256",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-structures-and-algorithms-nanodegree--nd256"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-structures-and-algorithms-nanodegree--nd256">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Data Structures and Algorithms
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - data-engineer-nanodegree--nd027",
#           "cta_message": "data-engineer-nanodegree--nd027",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-engineer-nanodegree--nd027"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-engineer-nanodegree--nd027">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Data Engineer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - intro-to-programming-nanodegree--nd000",
#           "cta_message": "intro-to-programming-nanodegree--nd000",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/intro-to-programming-nanodegree--nd000"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/intro-to-programming-nanodegree--nd000">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Introduction to Programming
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - ios-developer-nanodegree--nd003",
#           "cta_message": "ios-developer-nanodegree--nd003",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ios-developer-nanodegree--nd003"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ios-developer-nanodegree--nd003">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  iOS Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - react-nanodegree--nd019",
#           "cta_message": "react-nanodegree--nd019",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/react-nanodegree--nd019"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/react-nanodegree--nd019">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  React
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - blockchain-developer-nanodegree--nd1309",
#           "cta_message": "blockchain-developer-nanodegree--nd1309",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/blockchain-developer-nanodegree--nd1309"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/blockchain-developer-nanodegree--nd1309">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Blockchain Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - android-developer-nanodegree-by-google--nd801",
#           "cta_message": "android-developer-nanodegree-by-google--nd801",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/android-developer-nanodegree-by-google--nd801"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/android-developer-nanodegree-by-google--nd801">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Android Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-programming - android-basics-nanodegree-by-google--nd803",
#           "cta_message": "android-basics-nanodegree-by-google--nd803",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/android-basics-nanodegree-by-google--nd803"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/android-basics-nanodegree-by-google--nd803">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Android Basics
#                 </div>
#                </a>
#               </li>
#              </ul>
#             </section>
#            </ir-nav-sub-menu>
#           </li>
#           <li _ngcontent-sc8="" class="catalog-nav-school ng-star-inserted">
#            <span _ngcontent-sc8="" class="open-subnav school-link" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Mobile Header Link Clicked - Catalog - school-of-ai",
#           "cta_message": "school-of-ai",
#           "cta_type": "link",
#           "cta_location": "/"
#         }' data-analytics-event="Navbar Link Clicked" schoolpath="school-of-ai">
#             Artificial Intelligence
#            </span>
#            <!-- -->
#            <ir-nav-sub-menu _ngcontent-sc8="" _nghost-sc20="" class="ng-star-inserted">
#             <section _ngcontent-sc20="" class="catalog-nav">
#              <ul _ngcontent-sc20="" class="catalog-nav--menu secondary-menu">
#               <!-- -->
#               <li _ngcontent-sc20="" class="close-subnav ng-star-inserted" data-analytics-attrs='{
#         "category": "Navbar Link",
#         "label": "Navbar Link - Header Link Clicked - Catalog",
#         "cta_message": "school-of-ai_subnav_mobile_close",
#         "cta_type": "link",
#         "cta_location": "/"
#       }' data-analytics-event="Navbar Link Clicked">
#                <div _ngcontent-sc20="" class="secondary-menu-item">
#                 <span _ngcontent-sc20="" class="back-icon">
#                  <svg _ngcontent-sc20="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#                   <path _ngcontent-sc20="" d="M9.414 15l6.293-6.293a1 1 0 1 0-1.414-1.414l-8 8a1 1 0 0 0 0 1.414l8 8a1 1 0 0 0 1.414-1.414L9.414 17H25a1 1 0 0 0 0-2H9.414z" fill-rule="nonzero">
#                   </path>
#                  </svg>
#                 </span>
#                 <span _ngcontent-sc20="" class="nav-back">
#                  Back to Menu
#                 </span>
#                </div>
#               </li>
#               <li _ngcontent-sc20="" class="secondary-menu-item--header">
#                <h6 _ngcontent-sc20="">
#                 Programs
#                </h6>
#               </li>
#               <!-- -->
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - intel-edge-ai-for-iot-developers-nanodegree--nd131",
#           "cta_message": "intel-edge-ai-for-iot-developers-nanodegree--nd131",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/intel-edge-ai-for-iot-developers-nanodegree--nd131"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/intel-edge-ai-for-iot-developers-nanodegree--nd131">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Intel® Edge AI for IoT Developers
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - ai-for-business-leaders--nd054",
#           "cta_message": "ai-for-business-leaders--nd054",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ai-for-business-leaders--nd054"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ai-for-business-leaders--nd054">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  AI for Business Leaders
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - intro-to-machine-learning-with-tensorflow-nanodegree--nd230",
#           "cta_message": "intro-to-machine-learning-with-tensorflow-nanodegree--nd230",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/intro-to-machine-learning-with-tensorflow-nanodegree--nd230"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/intro-to-machine-learning-with-tensorflow-nanodegree--nd230">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Intro to Machine Learning with TensorFlow
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - ai-product-manager-nanodegree--nd088",
#           "cta_message": "ai-product-manager-nanodegree--nd088",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ai-product-manager-nanodegree--nd088"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ai-product-manager-nanodegree--nd088">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  AI Product Manager
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - intro-to-machine-learning-nanodegree--nd229",
#           "cta_message": "intro-to-machine-learning-nanodegree--nd229",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/intro-to-machine-learning-nanodegree--nd229"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/intro-to-machine-learning-nanodegree--nd229">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Intro to Machine Learning with PyTorch
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - data-structures-and-algorithms-nanodegree--nd256",
#           "cta_message": "data-structures-and-algorithms-nanodegree--nd256",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-structures-and-algorithms-nanodegree--nd256"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-structures-and-algorithms-nanodegree--nd256">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Data Structures and Algorithms
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - machine-learning-engineer-nanodegree--nd009t",
#           "cta_message": "machine-learning-engineer-nanodegree--nd009t",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/machine-learning-engineer-nanodegree--nd009t"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/machine-learning-engineer-nanodegree--nd009t">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Machine Learning Engineer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - ai-programming-python-nanodegree--nd089",
#           "cta_message": "ai-programming-python-nanodegree--nd089",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ai-programming-python-nanodegree--nd089"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ai-programming-python-nanodegree--nd089">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  AI Programming with Python
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - deep-learning-nanodegree--nd101",
#           "cta_message": "deep-learning-nanodegree--nd101",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/deep-learning-nanodegree--nd101"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/deep-learning-nanodegree--nd101">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Deep Learning
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - ai-for-trading--nd880",
#           "cta_message": "ai-for-trading--nd880",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ai-for-trading--nd880"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ai-for-trading--nd880">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Artificial Intelligence for Trading
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - computer-vision-nanodegree--nd891",
#           "cta_message": "computer-vision-nanodegree--nd891",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/computer-vision-nanodegree--nd891"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/computer-vision-nanodegree--nd891">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Computer Vision
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - natural-language-processing-nanodegree--nd892",
#           "cta_message": "natural-language-processing-nanodegree--nd892",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/natural-language-processing-nanodegree--nd892"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/natural-language-processing-nanodegree--nd892">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Natural Language Processing
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - deep-reinforcement-learning-nanodegree--nd893",
#           "cta_message": "deep-reinforcement-learning-nanodegree--nd893",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/deep-reinforcement-learning-nanodegree--nd893"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/deep-reinforcement-learning-nanodegree--nd893">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Deep Reinforcement Learning
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-ai - ai-artificial-intelligence-nanodegree--nd898",
#           "cta_message": "ai-artificial-intelligence-nanodegree--nd898",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/ai-artificial-intelligence-nanodegree--nd898"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/ai-artificial-intelligence-nanodegree--nd898">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Artificial Intelligence
#                 </div>
#                </a>
#               </li>
#              </ul>
#             </section>
#            </ir-nav-sub-menu>
#           </li>
#           <li _ngcontent-sc8="" class="catalog-nav-school ng-star-inserted">
#            <span _ngcontent-sc8="" class="open-subnav school-link" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Mobile Header Link Clicked - Catalog - school-of-cloud-computing",
#           "cta_message": "school-of-cloud-computing",
#           "cta_type": "link",
#           "cta_location": "/"
#         }' data-analytics-event="Navbar Link Clicked" schoolpath="school-of-cloud-computing">
#             Cloud Computing
#            </span>
#            <!-- -->
#            <ir-nav-sub-menu _ngcontent-sc8="" _nghost-sc20="" class="ng-star-inserted">
#             <section _ngcontent-sc20="" class="catalog-nav">
#              <ul _ngcontent-sc20="" class="catalog-nav--menu secondary-menu">
#               <!-- -->
#               <li _ngcontent-sc20="" class="close-subnav ng-star-inserted" data-analytics-attrs='{
#         "category": "Navbar Link",
#         "label": "Navbar Link - Header Link Clicked - Catalog",
#         "cta_message": "school-of-cloud-computing_subnav_mobile_close",
#         "cta_type": "link",
#         "cta_location": "/"
#       }' data-analytics-event="Navbar Link Clicked">
#                <div _ngcontent-sc20="" class="secondary-menu-item">
#                 <span _ngcontent-sc20="" class="back-icon">
#                  <svg _ngcontent-sc20="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#                   <path _ngcontent-sc20="" d="M9.414 15l6.293-6.293a1 1 0 1 0-1.414-1.414l-8 8a1 1 0 0 0 0 1.414l8 8a1 1 0 0 0 1.414-1.414L9.414 17H25a1 1 0 0 0 0-2H9.414z" fill-rule="nonzero">
#                   </path>
#                  </svg>
#                 </span>
#                 <span _ngcontent-sc20="" class="nav-back">
#                  Back to Menu
#                 </span>
#                </div>
#               </li>
#               <li _ngcontent-sc20="" class="secondary-menu-item--header">
#                <h6 _ngcontent-sc20="">
#                 Programs
#                </h6>
#               </li>
#               <!-- -->
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-cloud-computing - aws-cloud-architect-nanodegree--nd063",
#           "cta_message": "aws-cloud-architect-nanodegree--nd063",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/aws-cloud-architect-nanodegree--nd063"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/aws-cloud-architect-nanodegree--nd063">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  AWS Cloud Architect
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-cloud-computing - cloud-developer-nanodegree--nd9990",
#           "cta_message": "cloud-developer-nanodegree--nd9990",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/cloud-developer-nanodegree--nd9990"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/cloud-developer-nanodegree--nd9990">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Cloud Developer
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-cloud-computing - cloud-dev-ops-nanodegree--nd9991",
#           "cta_message": "cloud-dev-ops-nanodegree--nd9991",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/cloud-dev-ops-nanodegree--nd9991"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/cloud-dev-ops-nanodegree--nd9991">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Cloud DevOps Engineer
#                 </div>
#                </a>
#               </li>
#              </ul>
#             </section>
#            </ir-nav-sub-menu>
#           </li>
#           <li _ngcontent-sc8="" class="catalog-nav-school ng-star-inserted">
#            <span _ngcontent-sc8="" class="open-subnav school-link" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Mobile Header Link Clicked - Catalog - school-of-data-science",
#           "cta_message": "school-of-data-science",
#           "cta_type": "link",
#           "cta_location": "/"
#         }' data-analytics-event="Navbar Link Clicked" schoolpath="school-of-data-science">
#             Data Science
#            </span>
#            <!-- -->
#            <ir-nav-sub-menu _ngcontent-sc8="" _nghost-sc20="" class="ng-star-inserted">
#             <section _ngcontent-sc20="" class="catalog-nav">
#              <ul _ngcontent-sc20="" class="catalog-nav--menu secondary-menu">
#               <!-- -->
#               <li _ngcontent-sc20="" class="close-subnav ng-star-inserted" data-analytics-attrs='{
#         "category": "Navbar Link",
#         "label": "Navbar Link - Header Link Clicked - Catalog",
#         "cta_message": "school-of-data-science_subnav_mobile_close",
#         "cta_type": "link",
#         "cta_location": "/"
#       }' data-analytics-event="Navbar Link Clicked">
#                <div _ngcontent-sc20="" class="secondary-menu-item">
#                 <span _ngcontent-sc20="" class="back-icon">
#                  <svg _ngcontent-sc20="" height="32" style="fill:#ffffff" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#                   <path _ngcontent-sc20="" d="M9.414 15l6.293-6.293a1 1 0 1 0-1.414-1.414l-8 8a1 1 0 0 0 0 1.414l8 8a1 1 0 0 0 1.414-1.414L9.414 17H25a1 1 0 0 0 0-2H9.414z" fill-rule="nonzero">
#                   </path>
#                  </svg>
#                 </span>
#                 <span _ngcontent-sc20="" class="nav-back">
#                  Back to Menu
#                 </span>
#                </div>
#               </li>
#               <li _ngcontent-sc20="" class="secondary-menu-item--header">
#                <h6 _ngcontent-sc20="">
#                 Programs
#                </h6>
#               </li>
#               <!-- -->
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-data-science - data-streaming-nanodegree--nd029",
#           "cta_message": "data-streaming-nanodegree--nd029",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-streaming-nanodegree--nd029"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-streaming-nanodegree--nd029">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Data Streaming
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-data-science - data-visualization-nanodegree--nd197",
#           "cta_message": "data-visualization-nanodegree--nd197",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-visualization-nanodegree--nd197"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-visualization-nanodegree--nd197">
#                 <div _ngcontent-sc20="" class="secondary-menu-item">
#                  Data Visualization
#                 </div>
#                </a>
#               </li>
#               <li _ngcontent-sc20="" class="ng-star-inserted">
#                <a _ngcontent-sc20="" data-analytics-attrs='{
#           "category": "Navbar Link",
#           "label": "Navbar Link - Header Link Clicked - Catalog - school-of-data-science - data-structures-and-algorithms-nanodegree--nd256",
#           "cta_message": "data-structures-and-algorithms-nanodegree--nd256",
#           "cta_type": "link",
#           "cta_location": "/",
#           "cta_destination": "course/data-structures-and-algorithms-nanodegree--nd256"
#         }' data-analytics-event="Navbar Link Clicked" href="/course/data-structures-and-algorithms-nanodegree--nd256">
# ...
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://www.udacity.com/instructors">
#               Become an Instructor
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://www.udacity.com/intersect">
#               Udacity Intersect
#              </a>
#             </li>
#            </ul>
#           </ir-footer-nav>
#           <ir-footer-nav _ngcontent-sc5="" _nghost-sc14="" class="ng-star-inserted">
#            <p _ngcontent-sc14="" class="h6 mb-half">
#             Enterprise
#            </p>
#            <ul _ngcontent-sc14="">
#             <!-- -->
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://www.udacity.com/enterprise">
#               Udacity for Enterprise
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://www.udacity.com/hire-talent">
#               Hire Talent
#              </a>
#             </li>
#            </ul>
#           </ir-footer-nav>
#           <!-- -->
#          </li>
#          <li _ngcontent-sc5="" class="footer__nav__col ng-star-inserted">
#           <!-- -->
#           <ir-footer-nav _ngcontent-sc5="" _nghost-sc14="" class="ng-star-inserted">
#            <p _ngcontent-sc14="" class="h6 mb-half">
#             Support
#            </p>
#            <ul _ngcontent-sc14="">
#             <!-- -->
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="/contact">
#               Contact Us
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://udacity.zendesk.com/hc/en-us">
#               Help and FAQ
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="http://status.udacity.com">
#               Service Status
#              </a>
#             </li>
#             <li _ngcontent-sc14="" class="href text ng-star-inserted">
#              <a _ngcontent-sc14="" href="https://www.udacity.com/tech-requirements">
#               Tech Requirements
#              </a>
#             </li>
#            </ul>
#           </ir-footer-nav>
#           <!-- -->
#          </li>
#         </ul>
#        </nav>
#        <section _ngcontent-sc5="" class="footer__secondary">
#         <div _ngcontent-sc5="" class="footer__col">
#          <ul _ngcontent-sc5="" class="fineprint">
#           <li _ngcontent-sc5="">
#            <p _ngcontent-sc5="" class="small mb-0">
#             © 2011–2020 Udacity, Inc.
#            </p>
#           </li>
#           <!-- -->
#           <li _ngcontent-sc5="" class="fineprint__link ng-star-inserted">
#            <a _ngcontent-sc5="" href="/legal" id="ga-b93331" rel="nofollow">
#             Legal &amp; Privacy
#            </a>
#           </li>
#           <!-- -->
#           <li _ngcontent-sc5="" class="fineprint__link hidden-sm-down">
#            <a _ngcontent-sc5="" href="/sitemap">
#             Site Map
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div _ngcontent-sc5="" class="footer__col">
#          <!-- -->
#          <ir-nav-countries _ngcontent-sc5="" _nghost-sc16="" class="ng-star-inserted">
#           <div _ngcontent-sc16="" class="locales">
#            <div _ngcontent-sc16="" class="container" id="footer-geo-toggle-placeholder">
#             <div _ngcontent-sc16="" class="select">
#              <input _ngcontent-sc16="" class="selected-value" id="footer-geo-toggle" type="hidden" value="#"/>
#              <a _ngcontent-sc16="" class="selected">
#               <img _ngcontent-sc16="" alt="selected-flag" class="selected-image" src="/assets/iridium/images/shared/flags/icon-flag-us.svg"/>
#               <label _ngcontent-sc16="" class="selected-text">
#                United States
#               </label>
#              </a>
#              <span _ngcontent-sc16="" class="pointer pointer-down">
#               <svg _ngcontent-sc16="" enable-background="new 0 0 13 7" viewbox="0 0 13 7" xmlns="http://www.w3.org/2000/svg">
#                <path _ngcontent-sc16="" d="M6.5 7L0 1.5 1.3 0l5.2 4.4L11.7 0 13 1.5z" fill="#2E3D49">
#                </path>
#               </svg>
#              </span>
#             </div>
#             <!-- -->
#             <ul _ngcontent-sc16="" class="options click-off-close ng-star-inserted">
#              <!-- -->
#              <li _ngcontent-sc16="" class="ng-star-inserted">
#               <a _ngcontent-sc16="" class="option" href="https://cn.udacity.com" region="cn">
#                <img _ngcontent-sc16="" alt="China" class="option-image" src="/assets/iridium/images/shared/flags/icon-flag-cn.svg"/>
#                <label _ngcontent-sc16="" class="option-text">
#                 China
#                </label>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </ir-nav-countries>
#          <!-- -->
#          <ir-footer-social _ngcontent-sc5="" _nghost-sc17="" class="ng-star-inserted">
#           <!-- -->
#           <ul _ngcontent-sc17="" class="social">
#            <!-- -->
#            <li _ngcontent-sc17="" class="ng-star-inserted">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc17="" class="ng-star-inserted" href="https://www.facebook.com/Udacity" id="ga-facebook" rel="nofollow noopener noreferrer" target="_blank" title="Facebook">
#              <!-- -->
#              <!-- -->
#              <!-- -->
#              <img _ngcontent-sc17="" class="social__icon ng-star-inserted" deferimgsrc="/assets/iridium/images/core/footer/footer-social/facebook.svg" irdeferimage="" src="/assets/iridium/images/shared/placeholder.png" srcset="/assets/iridium/images/shared/placeholder.png 1x"/>
#              <!-- -->
#              <!-- -->
#             </a>
#             <!-- -->
#             <!-- -->
#            </li>
#            <li _ngcontent-sc17="" class="ng-star-inserted">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc17="" class="ng-star-inserted" href="https://twitter.com/udacity" id="ga-twitter" rel="nofollow noopener noreferrer" target="_blank" title="Twitter">
#              <!-- -->
#              <!-- -->
#              <!-- -->
#              <img _ngcontent-sc17="" class="social__icon ng-star-inserted" deferimgsrc="/assets/iridium/images/core/footer/footer-social/twitter.svg" irdeferimage="" src="/assets/iridium/images/shared/placeholder.png" srcset="/assets/iridium/images/shared/placeholder.png 1x"/>
#              <!-- -->
#              <!-- -->
#             </a>
#             <!-- -->
#             <!-- -->
#            </li>
#            <li _ngcontent-sc17="" class="ng-star-inserted">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc17="" class="ng-star-inserted" href="https://medium.com/udacity" id="ga-medium" rel="nofollow noopener noreferrer" target="_blank" title="Medium">
#              <!-- -->
#              <!-- -->
#              <!-- -->
#              <img _ngcontent-sc17="" class="social__icon ng-star-inserted" deferimgsrc="/assets/iridium/images/core/footer/footer-social/medium.svg" irdeferimage="" src="/assets/iridium/images/shared/placeholder.png" srcset="/assets/iridium/images/shared/placeholder.png 1x"/>
#              <!-- -->
#              <!-- -->
#             </a>
#             <!-- -->
#             <!-- -->
#            </li>
#            <li _ngcontent-sc17="" class="ng-star-inserted">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc17="" class="ng-star-inserted" href="https://www.linkedin.com/company/udacity" id="ga-linkedin" rel="nofollow noopener noreferrer" target="_blank" title="LinkedIn">
#              <!-- -->
#              <!-- -->
#              <!-- -->
#              <img _ngcontent-sc17="" class="social__icon ng-star-inserted" deferimgsrc="/assets/iridium/images/core/footer/footer-social/linkedin.svg" irdeferimage="" src="/assets/iridium/images/shared/placeholder.png" srcset="/assets/iridium/images/shared/placeholder.png 1x"/>
#              <!-- -->
#              <!-- -->
#             </a>
#             <!-- -->
#             <!-- -->
#            </li>
#            <li _ngcontent-sc17="" class="ng-star-inserted">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc17="" class="ng-star-inserted" href="https://www.instagram.com/udacity/" id="ga-instagram" rel="nofollow noopener noreferrer" target="_blank" title="Instagram">
#              <!-- -->
#              <!-- -->
#              <!-- -->
#              <img _ngcontent-sc17="" class="social__icon ng-star-inserted" deferimgsrc="/assets/iridium/images/core/footer/footer-social/instagram.svg" irdeferimage="" src="/assets/iridium/images/shared/placeholder.png" srcset="/assets/iridium/images/shared/placeholder.png 1x"/>
#              <!-- -->
#              <!-- -->
#             </a>
#             <!-- -->
#             <!-- -->
#            </li>
#           </ul>
#           <!-- -->
#          </ir-footer-social>
#         </div>
#         <!-- -->
#        </section>
#        <section _ngcontent-sc5="" class="text-center">
#         <!-- -->
#         <p _ngcontent-sc5="" class="micro mb-half ng-star-inserted">
#          "Nanodegree" is a registered trademark of Udacity. © 2011–2020 Udacity, Inc.
#         </p>
#         <!-- -->
#         <p _ngcontent-sc5="" class="micro legible center mb-0 footer__small-disclaimer ng-star-inserted">
#          <!-- -->
#          Udacity is not an accredited university and we don't confer traditional degrees. Udacity Nanodegree programs represent collaborations with our industry partners who help us develop our content and who hire many of our program graduates.
#         </p>
#        </section>
#       </div>
#      </footer>
#     </ir-footer-contentful>
#     <ir-autopopup-modal _ngcontent-sc0="" _nghost-sc6="">
#      <ir-modal _ngcontent-sc6="" _nghost-sc13="" class="ng-tns-c13-2">
#       <div _ngcontent-sc13="" class="wrapper modal--no-padding">
#        <!-- -->
#        <!-- -->
#        <!-- -->
#        <!-- -->
#        <!-- -->
#        <!-- -->
#       </div>
#       <!-- -->
#      </ir-modal>
#      <!-- -->
#     </ir-autopopup-modal>
#     <ir-cookie-consent _ngcontent-sc0="" _nghost-sc7="" style="display:none;">
#      <ir-notification _ngcontent-sc7="" _nghost-sc19="" class="snackbar ng-tns-c19-3">
#       <div _ngcontent-sc19="" class="banner-container ng-trigger ng-trigger-shrinkUpAnimation" style="">
#        <div _ngcontent-sc19="" class="banner">
#         <span _ngcontent-sc7="" class="snackbar__content">
#          We use cookies to optimize site functionality, personalize content and ads, and give you the best possible experience.
#         </span>
#         <a _ngcontent-sc7="" class="snackbar__content" href="/legal/cookie-policy">
#          Learn More
#         </a>
#         <div _ngcontent-sc7="" class="accept-cookie">
#          <a _ngcontent-sc7="" class="button button--white accept-button">
#           Accept
#          </a>
#          <a _ngcontent-sc7="" class="snackbar__content" href="/legal/cookie-policy#cookie-preference">
#           Cookie Preferences
#          </a>
#         </div>
#         <!-- -->
#        </div>
#       </div>
#      </ir-notification>
#     </ir-cookie-consent>
#    </ir-content>
#   </ir-root>
#   <script src="runtime-es2015.fbef488c5e381a14f543.js" type="module">
#   </script>
#   <script src="polyfills-es2015.d4e72df4d39cdba74e31.js" type="module">
#   </script>
#   <script defer="" nomodule="" src="runtime-es5.5f32e34872ce40bc5cf2.js">
#   </script>
#   <script defer="" nomodule="" src="polyfills-es5.f000307d7c0f625f8b7f.js">
#   </script>
#   <script defer="" src="scripts.0ff312eb31880c12aac8.js">
#   </script>
#   <script src="main-es2015.5978a17a2eed22403198.js" type="module">
#   </script>
#   <script defer="" nomodule="" src="main-es5.2e6f9a9283cc4aaef462.js">
#   </script>
#   <script id="iridium-us-state" type="application/json">
#    {&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Programs&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;--nd&q;}}]},{&q;section&q;:&q;Skill Level&q;,&q;values&q;:[{&q;title&q;:&q;Beginner&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;beginner&q;}},{&q;title&q;:&q;Intermediate&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;intermediate&q;}},{&q;title&q;:&q;Advanced&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;advanced&q;}}]},{&q;section&q;:&q;Estimated Duration&q;,&q;values&q;:[{&q;title&q;:&q;&l;1 month&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:0,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:1,&q;rangeMaxInclusive&q;:false}},{&q;title&q;:&q;1 - 3 months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:1,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:3,&q;rangeMaxInclusive&q;:true}},{&q;title&q;:&q;3+ months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:3,&q;rangeMinInclusive&q;:true}}]}],&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-US&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Android Development&q;}},{&q;title&q;:&q;C++&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;C++&q;}},{&q;title&q;:&q;Career Advancement&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Career Advancement&q;}},{&q;title&q;:&q;CSS&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;CSS&q;}},{&q;title&q;:&q;Core Data&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Core Data&q;}},{&q;title&q;:&q;Deep Learning&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Deep Learning&q;}},{&q;title&q;:&q;Digital Marketing&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Digital Marketing&q;}},{&q;title&q;:&q;Display Ads&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Display Ads&q;}},{&q;title&q;:&q;Facebook Marketing&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Facebook Marketing&q;}},{&q;title&q;:&q;Google VR SDK for Unity&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Google VR SDK for Unity&q;}},{&q;title&q;:&q;HTML&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;HTML&q;}},{&q;title&q;:&q;Java programming&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Java programming&q;}},{&q;title&q;:&q;JavaScript&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;JavaScript&q;}},{&q;title&q;:&q;Jupyter Notebooks&q;,&q;propertyPa ...
#   </script>
#  </body>
# </html>

# %% [markdown]
# Look for selectors that contain the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
print(soup.title)
# Out:
# <title>Udacity</title>

# %%
# Extract school

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for summary in summaries:
    # append name and school of each summary to courses list

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
